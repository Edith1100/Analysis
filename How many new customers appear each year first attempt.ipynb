# %%
# Celem analizy jest zweryfikowanie jak wielu klientów przybywa z roku na rok
# Zwizualizowanie danych przy pomocy wykresu słupkowego
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
from datetime import datetime

# %%
# Wczytanie danych
customers = pd.read_csv('customers.csv', sep=";")
orders = pd.read_csv('orders.csv', sep=";", encoding="ISO-8859-1")

# %%
mergedOC = orders.merge(customers, on="customerid")

# %%
mergedOC.head(n=10)
# Out:
#    orderid  customerid  campaignid   orderdate              city state  \
# 0  1002854       45978        2141  2009-10-13            NEWTON    MA
# 1  1002855      125381        2173  2009-10-13      NEW ROCHELLE    NY
# 2  1002856      103122        2141  2011-06-02             MIAMI    FL
# 3  1002857      130980        2173  2009-10-14      E RUTHERFORD    NJ
# 4  1002886       48553        2141  2010-11-19         BALTIMORE    MD
# 5  1002887      106150        2173  2009-10-15          ROWAYTON    CT
# 6  1002888       27805        2173  2009-10-15      INDIANAPOLIS    IN
# 7  1002889       24546        2173  2009-10-15     PLEASANTVILLE    NY
# 8  1002890       43783        2173  2009-10-15  EAST STROUDSBURG    PA
# 9  1003004       15688        2173  2009-10-15   ROUND LAKE PARK    IL
#
#   zipcode paymenttype  totalprice  numorderlines  numunits  householdid  \
# 0    2459          VI      190.00              3         3     18991234
# 1   10804          VI       10.00              1         1     36173848
# 2   33137          AE       35.22              2         2     36204911
# 3    7073          AE       10.00              1         1     36173923
# 4   21218          VI       10.00              1         1     19227025
# 5    6853          AE       10.00              1         1     36185316
# 6   46240          VI       10.00              1         1     18368062
# 7   10570          MC       10.00              1         1     19319923
# 8   18301          DB       29.68              2         2     19130968
# 9   60073          DB       19.68              1         1     20542726
#
#   gender firstname
# 0      M     LOUIS
# 1      M   ANTHONY
# 2    NaN   MERRILL
# 3      F     MARIA
# 4    NaN        T.
# 5      M     CRAIG
# 6      F     SUSAN
# 7      M       JOE
# 8      M    ROBERT
# 9      M      BILL

# %%
# Ekstrakcja roku z kolumny orderDate
import datetime as dt
mergedOC['orderdate'] = pd.to_datetime(mergedOC['orderdate'])
mergedOC['year'] = mergedOC['orderdate'].dt.year

# %%
# Pogrupowanie zamówień według roku. Wynik przedstawia jak wiele gospodarstw zamawiało produkty w każdym roku.
# Niestety rezultaty nie odpowiadają na pytanie jak wiele gospodarstw zwiększało się z roku na rok. Pożądana liczba występuje
# tylko dla 2009 roku.
# Gspodarstwa, które zakupiły produkt w 2009, mogą dokonać zakupu również w późniejszych latach. tak więc wyniki od 2010
# zawierają skumulowaną wartość liczbową ilości gospodarstw domowych.
mergedOC=mergedOC.groupby(['year']).size().reset_index(name='NoOfHouseholds')
mergedOC
# Out:
#    year  NoOfHouseholds
# 0  2009            7653
# 1  2010           18384
# 2  2011           26615
# 3  2012           20254
# 4  2013           28090
# 5  2014           43501
# 6  2015           30032
# 7  2016           15030

# %%
mergedOC.plot.bar('year','NoOfHouseholds', alpha=.5, color='blue')

# Ustawienie nazw osi oraz tytułu:
plt.title("The number of new households that make purchases varies considerably from one year to another")
plt.ylabel('Amounts of households')
plt.xlabel('Date time')
# Out:
# Text(0.5,0,'Date time')
