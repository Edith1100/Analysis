# %% [markdown]
# Cel: wprowadzenie do szeregów czasowych

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error as mae

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dataworkshop/5dwchallenge_2019/master/challenge5/input/airmiles.csv')

# %%
df.head()
# Out:
#    time  airmiles
# 0  1937       412
# 1  1938       480
# 2  1939       683
# 3  1940      1052
# 4  1941      1385

# %%
plt.figure(figsize=(15,5))
plt.plot(df.time, df.airmiles, 'o-');

# %%
path = 'https://raw.githubusercontent.com/dataworkshop/5dwchallenge_2019/master/challenge5/input/airmiles.csv'
df = pd.read_csv(path, parse_dates=['time'], index_col='time')
df[['airmiles']].plot();

# %%
def linear_function(airmiles, k=None, b=0):
    mean_value = np.mean(airmiles)
    if k is None:
        return [mean_value] * len(airmiles)
    return [(k*idx) +b*idx for idx, _ in enumerate(airmiles)]

plt.figure(figsize=(15,5))
plt.plot(df.index, df.airmiles, 'o-', label='original', color='r');
plt.plot(df.index, linear_function(df.airmiles), 'x-', label='mean', color='blue');
plt.plot(df.index, quadratic_function(df.airmiles, k=58, b=1), 'v-', label='linear' , color='black');

plt.legend();

# %% [markdown]
# # Metryka sukcesu

# %%
print('mean:', mae(df.airmiles , linear_function(df.airmiles)))

print('linear:', mae(df.airmiles ,quadratic_function(df.airmiles, k=58, b=0.05)))
# Out:
# mean 8499.305555555557
# linear 724.0
